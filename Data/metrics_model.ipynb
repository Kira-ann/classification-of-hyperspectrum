# %% [markdown]
# # Метрики моделей

# %% [markdown]
# ## Catboost

# %%
from IPython.display import Image
Image("metrics/catboost_conf_matrix.png")

# %%
Image("metrics/catboost_ROC.png")

# %% [markdown]
# ## Lightboost

# %%
Image("metrics/lgb_conf_matrix.png")

# %%
Image("metrics/lgb_ROC.png")

# %% [markdown]
# ## XGBoost

# %%
Image("metrics/xgboost_conf_matrix.png")

# %%
Image("metrics/xgboost_ROC.png")
